# %%
import yaml
import os

# %%
name = 'new-denoise'

config = {
    'device': 'cuda',
    
    'avi': {
        'enabled': True,
        'sigma_range': [-5, 5],
#         'range': [0, 4000]
    },
    
    'model': {
        'type': 'spatial-unet-2d-temporal-denoiser',
        
        'use_attention': False,
        'use_layer_norm': True,
        'use_padding': False,
        
        'padding_mode': 'reflect',
        'occlude_padding': False,
        
        'spatial_unet_feature_mode': 'repeat',
        
        'spatial_unet_padding': True,
        'spatial_unet_depth': 3,
        'spatial_unet_first_conv_channels': 32,
        'spatial_unet_n_conv_layers': 3,
        'spatial_unet_readout_kernel_size': 1,
        'spatial_unet_kernel_size': 3,
        'spatial_unet_activation': 'relu',
        
        'temporal_denoiser_n_conv_layers': 3,
        'temporal_denoiser_kernel_size': 5,
        'temporal_denoiser_conv_channels': 32,
        'temporal_denoiser_hidden_dense_layer_dims': [32, 32],
        'temporal_denoiser_activation': 'relu'
    }
}

with open(f'{name}.yaml', 'w') as file:
    yaml.dump(config, file)

# %%
name = 'spatial-unet-2d-temporal-denoiser-optosynth-const'

config = {
    'name': 'optosynth-const-lr',
    'device': 'cuda',
    'root_data_dir': '/home/jupyter/bw-data/cellmincer/data',
    'root_denoise_dir': '/home/jupyter/bw-data/cellmincer/denoise',
    'log_dir': '/home/jupyter/bw-data/cellmincer/logs',
    
    'model_state_path': '/home/jupyter/bw-data/cellmincer/models/optosynth-const-lr-2/model.pt',
    'write_avi': True,
    
    'datasets': [
        'optosynth_first_wave__1__20__50',
#         'optosynth_first_wave__2__20__50',
#         'optosynth_first_wave__3__20__50',
#         'optosynth_first_wave__4__20__50',
#         'optosynth_first_wave__5__20__50'
    ],
    
    'model': {
        'type': 'spatial-unet-2d-temporal-denoiser',
        
        'use_attention': False,
        'use_global_features': True,
        'use_layer_norm': False,
        'use_padding': False,
        
        'spatial_unet_padding': True,
        'spatial_unet_depth': 3,
        'spatial_unet_first_conv_channels': 32,
        'spatial_unet_n_conv_layers': 3,
        'spatial_unet_readout_kernel_size': 1,
        'spatial_unet_kernel_size': 3,
        'spatial_unet_activation': 'relu',
        'spatial_unet_batch_norm': False,
        
        'temporal_denoiser_n_conv_layers': 3,
        'temporal_denoiser_kernel_size': 5,
        'temporal_denoiser_conv_channels': 32,
        'temporal_denoiser_hidden_dense_layer_dims': [32, 32],
        'temporal_denoiser_activation': 'relu'
    }
}

with open(f'{name}.yaml', 'w') as file:
    yaml.dump(config, file)

# %%
name = 'spatial-unet-2d-temporal-denoiser-optosynth-cosine-anneal'

config = {
    'name': 'optosynth-cosine-anneal',
    'device': 'cuda',
    'root_data_dir': '/home/jupyter/bw-data/cellmincer/data',
    'root_denoise_dir': '/home/jupyter/bw-data/cellmincer/denoise',
    'log_dir': '/home/jupyter/bw-data/cellmincer/logs',
    
    'model_state_path': '/home/jupyter/bw-data/cellmincer/models/optosynth-cosine-anneal/final/model_state.pt',
    'write_avi': True,
    
    'datasets': [
        'optosynth_first_wave__1__20__50'
    ],
    
    'model': {
        'type': 'spatial-unet-2d-temporal-denoiser',
        
        'use_attention': False,
        'use_global_features': True,
        'use_layer_norm': False,
        'use_padding': False,
        
        'spatial_unet_padding': True,
        'spatial_unet_depth': 3,
        'spatial_unet_first_conv_channels': 32,
        'spatial_unet_n_conv_layers': 3,
        'spatial_unet_readout_kernel_size': 1,
        'spatial_unet_kernel_size': 3,
        'spatial_unet_activation': 'relu',
        'spatial_unet_batch_norm': False,
        
        'temporal_denoiser_n_conv_layers': 3,
        'temporal_denoiser_kernel_size': 5,
        'temporal_denoiser_conv_channels': 32,
        'temporal_denoiser_hidden_dense_layer_dims': [32, 32],
        'temporal_denoiser_activation': 'relu'
    }
}

with open(f'{name}.yaml', 'w') as file:
    yaml.dump(config, file)

# %%
name = 'spatial-unet-2d-temporal-denoiser-miller-ephys-standard'

config = {
    'name': 'miller-ephys-standard',
    'device': 'cuda',
    'root_data_dir': '/home/jupyter/bw-data/cellmincer/data',
    'root_denoise_dir': '/home/jupyter/bw-data/cellmincer/denoise',
    'log_dir': '/home/jupyter/bw-data/cellmincer/logs',
    
    'model_state_path': '/home/jupyter/bw-data/cellmincer/models/miller-ephys-standard/000000/model_state.pt',
    'write_avi': True,
    
    'datasets': [
        'cell_3_1_MMStack_Pos0',
#         'cell_3_2_MMStack_Pos0',
#         'std_1_MMStack_Pos0',
#         'std_2_MMStack_Pos0',
#         'std_3_MMStack_Pos0'
    ],
    
    'model': {
        'type': 'spatial-unet-2d-temporal-denoiser',
        
        'use_attention': False,
        'use_global_features': True,
        'use_layer_norm': False,
        'use_padding': False,
        
        'spatial_unet_padding': True,
        'spatial_unet_depth': 3,
        'spatial_unet_first_conv_channels': 32,
        'spatial_unet_n_conv_layers': 3,
        'spatial_unet_readout_kernel_size': 1,
        'spatial_unet_kernel_size': 3,
        'spatial_unet_activation': 'relu',
        'spatial_unet_batch_norm': False,
        
        'temporal_denoiser_n_conv_layers': 3,
        'temporal_denoiser_kernel_size': 5,
        'temporal_denoiser_conv_channels': 32,
        'temporal_denoiser_hidden_dense_layer_dims': [32, 32],
        'temporal_denoiser_activation': 'relu'
    }
}

with open(f'{name}.yaml', 'w') as file:
    yaml.dump(config, file)
